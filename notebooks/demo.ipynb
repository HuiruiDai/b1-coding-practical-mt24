# %%
# Add relevant Jupyter notebook extensions 
# %load_ext autoreload
# %autoreload 2

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['/Users/huiruidai/Documents/Oxford/3rd Year/B1 Engineering Computation/Scientific Coding/Coding Practical/b1-coding-practical-mt24/uuv_mission', '/Users/huiruidai/Documents/Oxford/3rd Year/B1 Engineering Computation/Scientific Coding/Coding Practical/b1-coding-practical-mt24/notebooks', '/Users/huiruidai/miniconda3/envs/b1cnv/lib/python311.zip', '/Users/huiruidai/miniconda3/envs/b1cnv/lib/python3.11', '/Users/huiruidai/miniconda3/envs/b1cnv/lib/python3.11/lib-dynload', '', '/Users/huiruidai/miniconda3/envs/b1cnv/lib/python3.11/site-packages', '/Users/huiruidai/miniconda3/envs/b1cnv/lib/python3.11/site-packages/setuptools/_vendor']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
import numpy as np
from controller import PDController
from dynamic import Submarine, ClosedLoop, Mission

# Create a PD controller with specified gains
kp = 0.15
kd = 0.6
controller = PDController(kp = kp, kd = kd)

# Create the submarine plant
sub = Submarine()

# Instantiate your controller (depending on your implementation)
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv("../data/mission.csv")

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
